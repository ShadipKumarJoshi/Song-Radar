# %% [markdown]
# # Using Spotify API to get top tracks of an artist using the Spotipy library

# %%
import os
import time
from datetime import datetime
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from dotenv import load_dotenv

# %%
load_dotenv() # load environment variables

client_id = os.getenv('SPOTIFY_CLIENT_ID')
client_secret = os.getenv('SPOTIFY_CLIENT_SECRET')

# spotipy setup
client_credentials_manager = SpotifyClientCredentials(client_id, client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %% [markdown]
# ### Check and expand data from million song subset

# %%
million_songs_df = pd.read_csv('../data/clean/million_songs_df.csv')

BATCH_SIZE = 50
SLEEP_TIME = 30

# get the last processed index from existing backup file
backup_file = '../data/local/spotify_million_tracks.csv'
if os.path.exists(backup_file):
    processed_df = pd.read_csv(backup_file)
    start_index = len(processed_df)
    print(f'Resuming from index {start_index}')
else:
    start_index = 0
    print('Starting new processing')

# process in batches
for start_idx in range(start_index, len(million_songs_df), BATCH_SIZE):
    batch = million_songs_df.iloc[start_idx:start_idx + BATCH_SIZE]
    tracks_data = []
    
    print(f'\nProcessing batch {start_idx//BATCH_SIZE + 1} of {len(million_songs_df)//BATCH_SIZE + 1}')
    print(f'Processing rows {start_idx} to {min(start_idx + BATCH_SIZE, len(million_songs_df))}')
    
    for i, row in batch.iterrows():
        try:
            # search track
            results = sp.search(q=f'track:{row["song_title"]} artist:{row["artist"]}', type='track', limit=1)
            
            if results['tracks']['items']:
                track = results['tracks']['items'][0]
                
                # get genres
                artist_id = track['artists'][0]['id']
                artist_info = sp.artist(artist_id)
                genres = artist_info['genres']
                
                tracks_data.append({
                    'original_title': row['song_title'],
                    'original_artist': row['artist'],
                    'spotify_title': track['name'],
                    'spotify_artist': track['artists'][0]['name'],
                    'album': track['album']['name'],
                    'release_date': track['album']['release_date'],
                    'popularity': track['popularity'],
                    'duration_ms': track['duration_ms'],
                    'explicit': track['explicit'],
                    'album_cover': track['album']['images'][0]['url'] if track['album']['images'] else None,
                    'genres': genres if genres else None
                })
                
        except Exception as e:
            print(f'Error processing track {row["song_title"]}: {str(e)}')
            continue
    
    # save batch results
    if tracks_data:
        temp_df = pd.DataFrame(tracks_data)
        temp_df.to_csv(backup_file, 
                      mode='a', 
                      header=not os.path.exists(backup_file), 
                      index=False)
        
        timestamp = datetime.now().strftime('%H:%M:%S')
        print(f'Batch completed at {timestamp}')
        print(f'Processed {len(tracks_data)} tracks in this batch')
        print(f'Total tracks processed: {start_idx + len(tracks_data)}')
        print(f'Last track processed: {row["song_title"]}')
        print(f'Last track genres: {genres if genres else "No genres found"}')
        
        if start_idx + BATCH_SIZE < len(million_songs_df):  # don't sleep after the last batch
            print(f'Sleeping for {SLEEP_TIME} seconds...')
            print('-' * 50)
            time.sleep(SLEEP_TIME)

print(f'\nAll batches processed!')
print(f'Final total tracks processed: {start_idx + len(tracks_data)}')
# Out:
# Starting new processing
#
# Processing batch 1 of 201
# Processing rows 0 to 50
# Batch completed at 10:59:08
# Processed 46 tracks in this batch
# Total tracks processed: 46
# Last track processed: Washington Post
# Last track genres: No genres found
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 2 of 201
# Processing rows 50 to 100
# Batch completed at 10:59:59
# Processed 45 tracks in this batch
# Total tracks processed: 95
# Last track processed: From My Hands
# Last track genres: ['deathcore', 'death metal', 'metalcore']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 3 of 201
# Processing rows 100 to 150
# Batch completed at 11:00:50
# Processed 42 tracks in this batch
# Total tracks processed: 142
# Last track processed: Bubblin'
# Last track genres: ['east coast hip hop', 'jazz rap']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 4 of 201
# Processing rows 150 to 200
# Batch completed at 11:01:40
# Processed 42 tracks in this batch
# Total tracks processed: 192
# Last track processed: Porque Nos Queremos
# Last track genres: ['flamenco', 'flamenco pop']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 5 of 201
# Processing rows 200 to 250
# Batch completed at 11:02:32
# Processed 43 tracks in this batch
# Total tracks processed: 243
# Last track processed: Tuesday Afternoon
# Last track genres: ['progressive rock', 'symphonic rock', 'art rock', 'blues', 'baroque pop', 'psychedelic rock']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 6 of 201
# Processing rows 250 to 300
# Batch completed at 11:03:23
# Processed 44 tracks in this batch
# Total tracks processed: 294
# Last track processed: Althea Cooley
# Last track genres: ['comedy']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 7 of 201
# Processing rows 300 to 350
# Batch completed at 11:04:13
# Processed 43 tracks in this batch
# Total tracks processed: 343
# Last track processed: Tenderly
# Last track genres: ['orchestra']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 8 of 201
# Processing rows 350 to 400
# Batch completed at 11:05:03
# Processed 44 tracks in this batch
# Total tracks processed: 394
# Last track processed: Back A Yard
# Last track genres: ['lovers rock', 'roots reggae', 'rocksteady', 'reggae']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 9 of 201
# Processing rows 400 to 450
# Batch completed at 11:05:54
# Processed 45 tracks in this batch
# Total tracks processed: 445
# Last track processed: Calm Down Dad
# Last track genres: No genres found
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 10 of 201
# Processing rows 450 to 500
# Batch completed at 11:06:43
# Processed 38 tracks in this batch
# Total tracks processed: 488
# Last track processed: Suck My Blood
# Last track genres: ['black metal']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 11 of 201
# Processing rows 500 to 550
# Batch completed at 11:07:34
# Processed 39 tracks in this batch
# Total tracks processed: 539
# Last track processed: Good Texan
# Last track genres: ['blues', 'blues rock', 'modern blues']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 12 of 201
# Processing rows 550 to 600
# Batch completed at 11:08:26
# Processed 45 tracks in this batch
# Total tracks processed: 595
# Last track processed: The Lull Before The Storm
# Last track genres: ['duranguense', 'música mexicana', 'banda']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 13 of 201
# Processing rows 600 to 650
# Batch completed at 11:09:20
# Processed 45 tracks in this batch
# Total tracks processed: 645
# Last track processed: Freight Train
# Last track genres: ['country blues', 'folk']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 14 of 201
# Processing rows 650 to 700
# Batch completed at 11:10:12
# Processed 38 tracks in this batch
# Total tracks processed: 688
# Last track processed: The Tie That Binds
# Last track genres: ['rockabilly', 'traditional country', 'honky tonk']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 15 of 201
# Processing rows 700 to 750
# Batch completed at 11:11:00
# Processed 40 tracks in this batch
# Total tracks processed: 740
# Last track processed: Smile
# Last track genres: ['gospel', 'worship']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 16 of 201
# Processing rows 750 to 800
# Batch completed at 11:11:51
# Processed 42 tracks in this batch
# Total tracks processed: 792
# Last track processed: Wolverine Blues
# Last track genres: ['big band', 'swing music']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 17 of 201
# Processing rows 800 to 850
# Batch completed at 11:12:40
# Processed 40 tracks in this batch
# Total tracks processed: 840
# Last track processed: Music Of The Sun
# Last track genres: No genres found
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 18 of 201
# Processing rows 850 to 900
# Batch completed at 11:13:32
# Processed 46 tracks in this batch
# Total tracks processed: 896
# Last track processed: After The Dark
# Last track genres: ['hardstyle', 'hardcore', 'frenchcore']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 19 of 201
# Processing rows 900 to 950
# Batch completed at 11:14:22
# Processed 37 tracks in this batch
# Total tracks processed: 937
# Last track processed: Pimpin' Don't Fail Me Now [Featuring Jazze Pha and Juvenile]
# Last track genres: ['avant-garde']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 20 of 201
# Processing rows 950 to 1000
# Batch completed at 11:15:14
# Processed 47 tracks in this batch
# Total tracks processed: 997
# Last track processed: Boo Hoo
# Last track genres: No genres found
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 21 of 201
# Processing rows 1000 to 1050
# Batch completed at 11:16:07
# Processed 41 tracks in this batch
# Total tracks processed: 1041
# Last track processed: Fabrication
# Last track genres: ['salsa', 'salsa romantica', 'merengue']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 22 of 201
# Processing rows 1050 to 1100
# Batch completed at 11:17:03
# Processed 47 tracks in this batch
# Total tracks processed: 1097
# Last track processed: Hohoemi No Bakudan
# Last track genres: ['anime', 'city pop']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 23 of 201
# Processing rows 1100 to 1150
# Batch completed at 11:17:53
# Processed 41 tracks in this batch
# Total tracks processed: 1141
# Last track processed: Sacred
# Last track genres: ['gothic metal', 'doom metal', 'symphonic metal', 'metal', 'black metal']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 24 of 201
# Processing rows 1150 to 1200
# Batch completed at 11:18:44
# Processed 43 tracks in this batch
# Total tracks processed: 1193
# Last track processed: Si Mi Chiamano Mimila Boheme Act1 Remast
# Last track genres: No genres found
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 25 of 201
# Processing rows 1200 to 1250
# Batch completed at 11:19:35
# Processed 41 tracks in this batch
# Total tracks processed: 1241
# Last track processed: Angel Of Light
# Last track genres: ['christian rock', 'ccm', 'christian']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 26 of 201
# Processing rows 1250 to 1300
# Batch completed at 11:20:27
# Processed 44 tracks in this batch
# Total tracks processed: 1294
# Last track processed: Little Louie Bonus
# Last track genres: No genres found
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 27 of 201
# Processing rows 1300 to 1350
# Batch completed at 11:21:20
# Processed 40 tracks in this batch
# Total tracks processed: 1340
# Last track processed: Water Blazz
# Last track genres: ['gothic metal', 'gabber', 'industrial']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 28 of 201
# Processing rows 1350 to 1400
# Batch completed at 11:22:13
# Processed 41 tracks in this batch
# Total tracks processed: 1391
# Last track processed: Dum Dum
# Last track genres: No genres found
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 29 of 201
# Processing rows 1400 to 1450
# Batch completed at 11:23:06
# Processed 46 tracks in this batch
# Total tracks processed: 1446
# Last track processed: Destined To Win
# Last track genres: ['ccm', 'christian rock', 'christian', 'pop worship', 'christian pop', 'chinese rock']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 30 of 201
# Processing rows 1450 to 1500
# Batch completed at 11:23:57
# Processed 43 tracks in this batch
# Total tracks processed: 1493
# Last track processed: Do It To Me
# Last track genres: ['medieval metal', 'german pop', 'medieval']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 31 of 201
# Processing rows 1500 to 1550
# Batch completed at 11:24:47
# Processed 41 tracks in this batch
# Total tracks processed: 1541
# Last track processed: This Is Our Album_ Eh?
# Last track genres: ['slowcore', 'dream pop']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 32 of 201
# Processing rows 1550 to 1600
# Batch completed at 11:25:36
# Processed 39 tracks in this batch
# Total tracks processed: 1589
# Last track processed: Close To The Well
# Last track genres: ['southern gospel', 'christian country', 'gospel']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 33 of 201
# Processing rows 1600 to 1650
