# %% [markdown]
# # Using Spotify API to get top tracks of an artist using the Spotipy library

# %%
import os
import time
from datetime import datetime
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from dotenv import load_dotenv

# %%
load_dotenv() # load environment variables

client_id = os.getenv('SPOTIFY_CLIENT_ID')
client_secret = os.getenv('SPOTIFY_CLIENT_SECRET')

# spotipy setup
client_credentials_manager = SpotifyClientCredentials(client_id, client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %% [markdown]
# ### Check and expand data from million song subset

# %%
million_songs_df = pd.read_csv('../data/clean/million_songs_df.csv')

BATCH_SIZE = 50
SLEEP_TIME = 30

# get the last processed index from existing backup file
backup_file = '../data/local/spotify_million_tracks.csv'
if os.path.exists(backup_file):
    processed_df = pd.read_csv(backup_file)
    start_index = len(processed_df)
    print(f'Resuming from index {start_index}')
else:
    start_index = 0
    print('Starting new processing')

# process in batches
for start_idx in range(start_index, len(million_songs_df), BATCH_SIZE):
    batch = million_songs_df.iloc[start_idx:start_idx + BATCH_SIZE]
    tracks_data = []
    
    print(f'\nProcessing batch {start_idx//BATCH_SIZE + 1} of {len(million_songs_df)//BATCH_SIZE + 1}')
    print(f'Processing rows {start_idx} to {min(start_idx + BATCH_SIZE, len(million_songs_df))}')
    
    for i, row in batch.iterrows():
        try:
            # search track
            results = sp.search(q=f'track:{row["song_title"]} artist:{row["artist"]}', type='track', limit=1)
            
            if results['tracks']['items']:
                track = results['tracks']['items'][0]
                
                # get genres
                artist_id = track['artists'][0]['id']
                artist_info = sp.artist(artist_id)
                genres = artist_info['genres']
                
                tracks_data.append({
                    'original_title': row['song_title'],
                    'original_artist': row['artist'],
                    'spotify_title': track['name'],
                    'spotify_artist': track['artists'][0]['name'],
                    'album': track['album']['name'],
                    'release_date': track['album']['release_date'],
                    'popularity': track['popularity'],
                    'duration_ms': track['duration_ms'],
                    'explicit': track['explicit'],
                    'album_cover': track['album']['images'][0]['url'] if track['album']['images'] else None,
                    'genres': genres if genres else None
                })
                
        except Exception as e:
            print(f'Error processing track {row["song_title"]}: {str(e)}')
            continue
    
    # save batch results
    if tracks_data:
        temp_df = pd.DataFrame(tracks_data)
        temp_df.to_csv(backup_file, 
                      mode='a', 
                      header=not os.path.exists(backup_file), 
                      index=False)
        
        timestamp = datetime.now().strftime('%H:%M:%S')
        print(f'Batch completed at {timestamp}')
        print(f'Processed {len(tracks_data)} tracks in this batch')
        print(f'Total tracks processed: {start_idx + len(tracks_data)}')
        print(f'Last track processed: {row["song_title"]}')
        print(f'Last track genres: {genres if genres else "No genres found"}')
        
        if start_idx + BATCH_SIZE < len(million_songs_df):  # don't sleep after the last batch
            print(f'Sleeping for {SLEEP_TIME} seconds...')
            print('-' * 50)
            time.sleep(SLEEP_TIME)

print(f'\nAll batches processed!')
print(f'Final total tracks processed: {start_idx + len(tracks_data)}')
# Out:
# Resuming from index 1940
#
# Processing batch 39 of 201
# Processing rows 1940 to 1990
# Batch completed at 12:26:11
# Processed 41 tracks in this batch
# Total tracks processed: 1981
# Last track processed: The Imperial March from The Empire Strikes Back
# Last track genres: ['soundtrack']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 40 of 201
# Processing rows 1990 to 2040
# HTTP Error for GET to https://api.spotify.com/v1/search with Params: {'q': "track:Dialogue et final si j'avais su artist:Maurice Chevalier / Françoise Dorin / Marina Hottine / Suzanne Gabriello / Jo Charrier / Marcel Carpentier / Perrette Souplex / Andree Grandjean / Cadet Rivers / Raymond Girerd / Orchestre De Jacques-Henri Rys / Jacques Henri Rys", 'limit': 1, 'offset': 0, 'type': 'track', 'market': None} returned 400 due to Query exceeds maximum length of 250 characters
# Error processing track Dialogue et final si j'avais su: http status: 400, code:-1 - https://api.spotify.com/v1/search?q=track%3ADialogue+et+final+si+j%27avais+su+artist%3AMaurice+Chevalier+%2F+Fran%C3%A7oise+Dorin+%2F+Marina+Hottine+%2F+Suzanne+Gabriello+%2F+Jo+Charrier+%2F+Marcel+Carpentier+%2F+Perrette+Souplex+%2F+Andree+Grandjean+%2F+Cadet+Rivers+%2F+Raymond+Girerd+%2F+Orchestre+De+Jacques-Henri+Rys+%2F+Jacques+Henri+Rys&limit=1&offset=0&type=track:
#  Query exceeds maximum length of 250 characters, reason: None
# Batch completed at 12:27:01
# Processed 42 tracks in this batch
# Total tracks processed: 2032
# Last track processed: Unholy Outburst #3
# Last track genres: ['minimal techno', 'electronica']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 41 of 201
# Processing rows 2040 to 2090
# Batch completed at 12:27:50
# Processed 40 tracks in this batch
# Total tracks processed: 2080
# Last track processed: Midnight
# Last track genres: ['rockabilly', 'dansband', 'boogie-woogie', 'rock and roll']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 42 of 201
# Processing rows 2090 to 2140
# Batch completed at 12:28:40
# Processed 42 tracks in this batch
# Total tracks processed: 2132
# Last track processed: La Coloreteada
# Last track genres: ['grupera', 'cumbia']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 43 of 201
# Processing rows 2140 to 2190
# Batch completed at 12:29:29
# Processed 37 tracks in this batch
# Total tracks processed: 2177
# Last track processed: In My Arms
# Last track genres: No genres found
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 44 of 201
# Processing rows 2190 to 2240
# Batch completed at 12:30:19
# Processed 40 tracks in this batch
# Total tracks processed: 2230
# Last track processed: I Can't Break Away
# Last track genres: ['northern soul']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 45 of 201
# Processing rows 2240 to 2290
# Batch completed at 12:31:09
# Processed 42 tracks in this batch
# Total tracks processed: 2282
# Last track processed: Chim Chim Cheree
# Last track genres: ['funky house']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 46 of 201
# Processing rows 2290 to 2340
# Batch completed at 12:32:01
# Processed 48 tracks in this batch
# Total tracks processed: 2338
# Last track processed: Bridge To Canada
# Last track genres: No genres found
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 47 of 201
# Processing rows 2340 to 2390
# Batch completed at 12:32:52
# Processed 45 tracks in this batch
# Total tracks processed: 2385
# Last track processed: Spanish Shuffle
# Last track genres: ['latin rock']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 48 of 201
# Processing rows 2390 to 2440
# Batch completed at 12:33:45
# Processed 44 tracks in this batch
# Total tracks processed: 2434
# Last track processed: She Fell Away
# Last track genres: No genres found
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 49 of 201
# Processing rows 2440 to 2490
# Batch completed at 12:34:36
# Processed 47 tracks in this batch
# Total tracks processed: 2487
# Last track processed: Soul Deep
# Last track genres: No genres found
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 50 of 201
# Processing rows 2490 to 2540
# Batch completed at 12:35:27
# Processed 42 tracks in this batch
# Total tracks processed: 2532
# Last track processed: Johnny Loves Me
# Last track genres: ['doo-wop']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 51 of 201
# Processing rows 2540 to 2590
# Batch completed at 12:36:18
# Processed 46 tracks in this batch
# Total tracks processed: 2586
# Last track processed: Certain Things We Do
# Last track genres: ['east coast hip hop']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 52 of 201
# Processing rows 2590 to 2640
# Batch completed at 12:37:08
# Processed 43 tracks in this batch
# Total tracks processed: 2633
# Last track processed: Too Much Saturn
# Last track genres: No genres found
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 53 of 201
# Processing rows 2640 to 2690
# Error processing track Grim Prospects : HTTPSConnectionPool(host='api.spotify.com', port=443): Read timed out. (read timeout=5)
# Batch completed at 12:38:03
# Processed 43 tracks in this batch
# Total tracks processed: 2683
# Last track processed: God Save the Queen
# Last track genres: ['punk', 'proto-punk']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 54 of 201
# Processing rows 2690 to 2740
# Batch completed at 12:38:54
# Processed 44 tracks in this batch
# Total tracks processed: 2734
# Last track processed: Boxing Day
# Last track genres: ['progressive rock', 'progressive metal', 'art rock', 'symphonic rock']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 55 of 201
# Processing rows 2740 to 2790
# Batch completed at 12:39:45
# Processed 44 tracks in this batch
# Total tracks processed: 2784
# Last track processed: This Lullaby
# Last track genres: ['stoner rock', 'alternative rock']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 56 of 201
# Processing rows 2790 to 2840
# Batch completed at 12:40:35
# Processed 46 tracks in this batch
# Total tracks processed: 2836
# Last track processed: Vem Pr'a Roda
# Last track genres: ['brazilian jazz', 'latin jazz', 'bossa nova', 'jazz funk']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 57 of 201
# Processing rows 2840 to 2890
# Batch completed at 12:41:24
# Processed 37 tracks in this batch
# Total tracks processed: 2877
# Last track processed: Will Not Fade  )
# Last track genres: ['christian rock', 'ccm', 'christian', 'christian alternative rock', 'christian pop', 'pop worship']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 58 of 201
# Processing rows 2890 to 2940
# Batch completed at 12:42:14
# Processed 46 tracks in this batch
# Total tracks processed: 2936
# Last track processed: Too Cool for Love
# Last track genres: ['rockabilly', 'roots rock', 'dansband', 'southern rock']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 59 of 201
# Processing rows 2940 to 2990
# Batch completed at 12:43:05
# Processed 42 tracks in this batch
# Total tracks processed: 2982
# Last track processed: Les Trois Orfèvres
# Last track genres: ['chanson', 'variété française']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 60 of 201
# Processing rows 2990 to 3040
# Batch completed at 12:43:55
# Processed 43 tracks in this batch
# Total tracks processed: 3033
# Last track processed: Tschung Mori
# Last track genres: No genres found
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 61 of 201
# Processing rows 3040 to 3090
# Batch completed at 12:44:45
# Processed 44 tracks in this batch
# Total tracks processed: 3084
# Last track processed: Shawty Get Loose
# Last track genres: ['miami bass', 'g-house']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 62 of 201
# Processing rows 3090 to 3140
# Batch completed at 12:45:34
# Processed 41 tracks in this batch
# Total tracks processed: 3131
# Last track processed: Xi Yang Wu Xian Hao
# Last track genres: ['cantopop', 'mandopop', 'c-pop', 'taiwanese pop']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 63 of 201
# Processing rows 3140 to 3190
# Batch completed at 12:46:24
# Processed 43 tracks in this batch
# Total tracks processed: 3183
# Last track processed: Out Of The Danger Zone
# Last track genres: ['ccm', 'christian rock', 'christian', 'pop worship', 'christian pop', 'chinese rock']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 64 of 201
# Processing rows 3190 to 3240
# Batch completed at 12:47:12
# Processed 38 tracks in this batch
# Total tracks processed: 3228
# Last track processed: Shadrach
# Last track genres: ['rap rock', 'east coast hip hop', 'hip hop']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 65 of 201
# Processing rows 3240 to 3290
# Batch completed at 12:48:01
# Processed 38 tracks in this batch
# Total tracks processed: 3278
# Last track processed: No Comprimise_ No Regrets
# Last track genres: ['tejano', 'roots rock', 'country rock']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 66 of 201
# Processing rows 3290 to 3340
# Batch completed at 12:48:51
# Processed 43 tracks in this batch
# Total tracks processed: 3333
# Last track processed: Why We Thugs
# Last track genres: ['gangster rap', 'west coast hip hop', 'g-funk']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 67 of 201
# Processing rows 3340 to 3390
# Batch completed at 12:49:40
# Processed 40 tracks in this batch
# Total tracks processed: 3380
# Last track processed: Star
# Last track genres: No genres found
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 68 of 201
# Processing rows 3390 to 3440
# Batch completed at 12:50:30
# Processed 44 tracks in this batch
# Total tracks processed: 3434
# Last track processed: Mr. Bozack
# Last track genres: ['gothic metal', 'avant-garde', 'industrial rock', 'doom metal']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 69 of 201
# Processing rows 3440 to 3490
# Batch completed at 12:51:20
# Processed 44 tracks in this batch
# Total tracks processed: 3484
# Last track processed: Miserere: XII. Ne Projicias
# Last track genres: ['christian country', 'southern gospel', 'comedy']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 70 of 201
# Processing rows 3490 to 3540
# Batch completed at 12:52:10
# Processed 45 tracks in this batch
# Total tracks processed: 3535
# Last track processed: Pus-Filled Carcass
# Last track genres: ['grindcore', 'death metal', 'sludge metal']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 71 of 201
# Processing rows 3540 to 3590
# Batch completed at 12:52:58
# Processed 39 tracks in this batch
# Total tracks processed: 3579
# Last track processed: Walking in Faith_ Reprise
# Last track genres: ['trance']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 72 of 201
# Processing rows 3590 to 3640
# Batch completed at 12:53:52
# Processed 47 tracks in this batch
# Total tracks processed: 3637
# Last track processed: Family Galaxy
# Last track genres: ['idm']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 73 of 201
# Processing rows 3640 to 3690
# Batch completed at 12:54:42
# Processed 44 tracks in this batch
# Total tracks processed: 3684
# Last track processed: Sfm
# Last track genres: ['big beat']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 74 of 201
# Processing rows 3690 to 3740
# Batch completed at 12:55:33
# Processed 47 tracks in this batch
# Total tracks processed: 3737
# Last track processed: Prick For President
# Last track genres: No genres found
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 75 of 201
# Processing rows 3740 to 3790
# Batch completed at 12:56:22
# Processed 43 tracks in this batch
# Total tracks processed: 3783
# Last track processed: Meditacao
# Last track genres: ['bossa nova', 'brazilian jazz', 'samba', 'latin jazz', 'cool jazz', 'jazz', 'mpb']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 76 of 201
# Processing rows 3790 to 3840
# Batch completed at 12:57:11
# Processed 40 tracks in this batch
# Total tracks processed: 3830
# Last track processed: Belly Dancer  Remix ft. Kardinal Offishall
# Last track genres: ['chanson']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 77 of 201
# Processing rows 3840 to 3890
# Batch completed at 12:58:01
# Processed 45 tracks in this batch
# Total tracks processed: 3885
# Last track processed: Hot Weiners
# Last track genres: No genres found
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 78 of 201
# Processing rows 3890 to 3940
# Batch completed at 12:58:51
# Processed 41 tracks in this batch
# Total tracks processed: 3931
# Last track processed: If We Loved
# Last track genres: ['country', 'acoustic country']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 79 of 201
# Processing rows 3940 to 3990
# Batch completed at 12:59:42
# Processed 45 tracks in this batch
# Total tracks processed: 3985
# Last track processed: Freedom
# Last track genres: ['ccm', 'christian']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 80 of 201
# Processing rows 3990 to 4040
# Batch completed at 13:00:31
# Processed 44 tracks in this batch
# Total tracks processed: 4034
# Last track processed: Crescent Moon
# Last track genres: ['trip hop', 'downtempo']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 81 of 201
# Processing rows 4040 to 4090
# Batch completed at 13:01:22
# Processed 49 tracks in this batch
# Total tracks processed: 4089
# Last track processed: Violence
# Last track genres: No genres found
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 82 of 201
# Processing rows 4090 to 4140
# Batch completed at 13:02:12
# Processed 45 tracks in this batch
# Total tracks processed: 4135
# Last track processed: God Will Make A Way
# Last track genres: ['southern gospel', 'christian country', 'gospel']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 83 of 201
# Processing rows 4140 to 4190
# Batch completed at 13:03:02
# Processed 44 tracks in this batch
# Total tracks processed: 4184
# Last track processed: If I Run
# Last track genres: No genres found
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 84 of 201
# Processing rows 4190 to 4240
# Batch completed at 13:03:52
# Processed 46 tracks in this batch
# Total tracks processed: 4236
# Last track processed: Bury Your Head
# Last track genres: ['post-hardcore', 'screamo', 'emo', 'emocore']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 85 of 201
# Processing rows 4240 to 4290
# Batch completed at 13:04:43
# Processed 40 tracks in this batch
# Total tracks processed: 4280
# Last track processed: My First Day At School
# Last track genres: ['celtic']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 86 of 201
# Processing rows 4290 to 4340
# Batch completed at 13:05:33
# Processed 43 tracks in this batch
# Total tracks processed: 4333
# Last track processed: A Costa De Galicia
# Last track genres: ['celtic']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 87 of 201
# Processing rows 4340 to 4390
# Batch completed at 13:06:23
# Processed 45 tracks in this batch
# Total tracks processed: 4385
# Last track processed: La sangre de tu tristeza
# Last track genres: No genres found
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 88 of 201
# Processing rows 4390 to 4440
# Batch completed at 13:07:14
# Processed 44 tracks in this batch
# Total tracks processed: 4434
# Last track processed: Toccata Et Fugue En Ré Mineur BWV 565
# Last track genres: ['classical', 'classical piano']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 89 of 201
# Processing rows 4440 to 4490
# Batch completed at 13:08:03
# Processed 42 tracks in this batch
# Total tracks processed: 4482
# Last track processed: Vincent
# Last track genres: ['rhumba']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 90 of 201
# Processing rows 4490 to 4540
# Batch completed at 13:08:52
# Processed 41 tracks in this batch
# Total tracks processed: 4531
# Last track processed: Something's Missing
# Last track genres: ['singer-songwriter']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 91 of 201
# Processing rows 4540 to 4590
# Batch completed at 13:09:41
# Processed 38 tracks in this batch
# Total tracks processed: 4578
# Last track processed: Marilyn
# Last track genres: ['finnish rock', 'iskelmä', 'finnish pop']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 92 of 201
# Processing rows 4590 to 4640
# Error processing track Chinoiserie: HTTPSConnectionPool(host='api.spotify.com', port=443): Read timed out. (read timeout=5)
# Batch completed at 13:10:36
# Processed 43 tracks in this batch
# Total tracks processed: 4633
# Last track processed: Sicilienne
# Last track genres: ['punk', 'proto-punk']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 93 of 201
# Processing rows 4640 to 4690
# Batch completed at 13:11:27
# Processed 45 tracks in this batch
# Total tracks processed: 4685
# Last track processed: Stairs To the Attic
# Last track genres: No genres found
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 94 of 201
# Processing rows 4690 to 4740
# Batch completed at 13:12:20
# Processed 47 tracks in this batch
# Total tracks processed: 4737
# Last track processed: You Are The One
# Last track genres: ['lovers rock', 'reggae', 'roots reggae']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 95 of 201
# Processing rows 4740 to 4790
# Batch completed at 13:13:10
# Processed 44 tracks in this batch
# Total tracks processed: 4784
# Last track processed: I Stayed Long Enough
# Last track genres: ['traditional country', 'country', 'honky tonk']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 96 of 201
# Processing rows 4790 to 4840
# Batch completed at 13:14:01
# Processed 44 tracks in this batch
# Total tracks processed: 4834
# Last track processed: Raining Revolution
# Last track genres: No genres found
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 97 of 201
# Processing rows 4840 to 4890
# Batch completed at 13:14:51
# Processed 43 tracks in this batch
# Total tracks processed: 4883
# Last track processed: Proud mary
# Last track genres: No genres found
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 98 of 201
# Processing rows 4890 to 4940
# Batch completed at 13:15:42
# Processed 44 tracks in this batch
# Total tracks processed: 4934
# Last track processed: Like It Like That
# Last track genres: ['jazz rap', 'east coast hip hop', 'hip hop']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 99 of 201
# Processing rows 4940 to 4990
# Batch completed at 13:16:32
# Processed 41 tracks in this batch
# Total tracks processed: 4981
# Last track processed: Fire
# Last track genres: ['glam metal', 'glam rock']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 100 of 201
# Processing rows 4990 to 5040
# Batch completed at 13:17:22
# Processed 41 tracks in this batch
# Total tracks processed: 5031
# Last track processed: Diamond In The Bluff
# Last track genres: ['deathcore']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 101 of 201
# Processing rows 5040 to 5090
# Batch completed at 13:18:12
# Processed 44 tracks in this batch
# Total tracks processed: 5084
# Last track processed: Miina ja Mikko markkinoilla
# Last track genres: ['iskelmä', 'finnish rock', 'finnish pop', 'polka']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 102 of 201
# Processing rows 5090 to 5140
# Batch completed at 13:19:01
# Processed 40 tracks in this batch
# Total tracks processed: 5130
# Last track processed: Fast-Track
# Last track genres: ['art rock', 'alternative rock']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 103 of 201
# Processing rows 5140 to 5190
# Batch completed at 13:19:52
# Processed 44 tracks in this batch
# Total tracks processed: 5184
# Last track processed: We Got You
# Last track genres: ['east coast hip hop', 'hip hop', 'jazz rap']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 104 of 201
# Processing rows 5190 to 5240
# Batch completed at 13:20:43
# Processed 46 tracks in this batch
# Total tracks processed: 5236
# Last track processed: Todo A Mi Favor
# Last track genres: ['trova', 'argentine rock', 'nueva trova', 'tango', 'folklore argentino']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 105 of 201
# Processing rows 5240 to 5290
# Batch completed at 13:21:33
# Processed 44 tracks in this batch
# Total tracks processed: 5284
# Last track processed: Genesis
# Last track genres: ['east coast hip hop']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 106 of 201
# Processing rows 5290 to 5340
# Batch completed at 13:22:24
# Processed 45 tracks in this batch
# Total tracks processed: 5335
# Last track processed: Roger Milla
# Last track genres: ['rhumba', 'champeta', 'azonto']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 107 of 201
# Processing rows 5340 to 5390
# Batch completed at 13:23:15
# Processed 44 tracks in this batch
# Total tracks processed: 5384
# Last track processed: Natural
# Last track genres: No genres found
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 108 of 201
# Processing rows 5390 to 5440
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 77647
