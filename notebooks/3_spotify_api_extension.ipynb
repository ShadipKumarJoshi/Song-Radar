# %% [markdown]
# # Using Spotify API to get top tracks of an artist using the Spotipy library

# %%
import os
import time
from datetime import datetime
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from dotenv import load_dotenv

# %%
load_dotenv() # load environment variables

client_id = os.getenv('SPOTIFY_CLIENT_ID')
client_secret = os.getenv('SPOTIFY_CLIENT_SECRET')

# spotipy setup
client_credentials_manager = SpotifyClientCredentials(client_id, client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %% [markdown]
# ### Check and expand data from million song subset

# %%
million_songs_df = pd.read_csv('../data/clean/million_songs_df.csv')

BATCH_SIZE = 50
SLEEP_TIME = 30

# get the last processed index from existing backup file
backup_file = '../data/local/spotify_million_tracks.csv'
if os.path.exists(backup_file):
    processed_df = pd.read_csv(backup_file)
    start_index = len(processed_df)
    print(f'Resuming from index {start_index}')
else:
    start_index = 0
    print('Starting new processing')

# process in batches
for start_idx in range(start_index, len(million_songs_df), BATCH_SIZE):
    batch = million_songs_df.iloc[start_idx:start_idx + BATCH_SIZE]
    tracks_data = []
    
    print(f'\nProcessing batch {start_idx//BATCH_SIZE + 1} of {len(million_songs_df)//BATCH_SIZE + 1}')
    print(f'Processing rows {start_idx} to {min(start_idx + BATCH_SIZE, len(million_songs_df))}')
    
    for i, row in batch.iterrows():
        try:
            # search track
            results = sp.search(q=f'track:{row["song_title"]} artist:{row["artist"]}', type='track', limit=1)
            
            if results['tracks']['items']:
                track = results['tracks']['items'][0]
                
                # get genres
                artist_id = track['artists'][0]['id']
                artist_info = sp.artist(artist_id)
                genres = artist_info['genres']
                
                tracks_data.append({
                    'original_title': row['song_title'],
                    'original_artist': row['artist'],
                    'spotify_title': track['name'],
                    'spotify_artist': track['artists'][0]['name'],
                    'album': track['album']['name'],
                    'release_date': track['album']['release_date'],
                    'popularity': track['popularity'],
                    'duration_ms': track['duration_ms'],
                    'explicit': track['explicit'],
                    'album_cover': track['album']['images'][0]['url'] if track['album']['images'] else None,
                    'genres': genres if genres else None
                })
                
        except Exception as e:
            print(f'Error processing track {row["song_title"]}: {str(e)}')
            continue
    
    # save batch results
    if tracks_data:
        temp_df = pd.DataFrame(tracks_data)
        temp_df.to_csv(backup_file, 
                      mode='a', 
                      header=not os.path.exists(backup_file), 
                      index=False)
        
        timestamp = datetime.now().strftime('%H:%M:%S')
        print(f'Batch completed at {timestamp}')
        print(f'Processed {len(tracks_data)} tracks in this batch')
        print(f'Total tracks processed: {start_idx + len(tracks_data)}')
        print(f'Last track processed: {row["song_title"]}')
        print(f'Last track genres: {genres if genres else "No genres found"}')
        
        if start_idx + BATCH_SIZE < len(million_songs_df):  # don't sleep after the last batch
            print(f'Sleeping for {SLEEP_TIME} seconds...')
            print('-' * 50)
            time.sleep(SLEEP_TIME)

print(f'\nAll batches processed!')
print(f'Final total tracks processed: {start_idx + len(tracks_data)}')
# Out:
# Resuming from index 4915
#
# Processing batch 99 of 201
# Processing rows 4915 to 4965
# Batch completed at 11:17:56
# Processed 42 tracks in this batch
# Total tracks processed: 4957
# Last track processed: Nada Mas
# Last track genres: ['big band']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 100 of 201
# Processing rows 4965 to 5015
# Batch completed at 11:18:53
# Processed 41 tracks in this batch
# Total tracks processed: 5006
# Last track processed: Impromptu
# Last track genres: No genres found
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 101 of 201
# Processing rows 5015 to 5065
# Batch completed at 11:19:51
# Processed 42 tracks in this batch
# Total tracks processed: 5057
# Last track processed: Buried Alive In The Blues
# Last track genres: ['blues', 'classic blues', 'blues rock']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 102 of 201
# Processing rows 5065 to 5115
# Batch completed at 11:20:47
# Processed 43 tracks in this batch
# Total tracks processed: 5108
# Last track processed: Bing
# Last track genres: ['glam metal', 'album rock']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 103 of 201
# Processing rows 5115 to 5165
# Batch completed at 11:21:43
# Processed 41 tracks in this batch
# Total tracks processed: 5156
# Last track processed: Future Traffic Song
# Last track genres: ['progressive trance', 'progressive house', 'breakbeat']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 104 of 201
# Processing rows 5165 to 5215
# Batch completed at 11:22:36
# Processed 45 tracks in this batch
# Total tracks processed: 5210
# Last track processed: I Love You Baby
# Last track genres: ['lovers rock', 'riddim', 'reggae']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 105 of 201
# Processing rows 5215 to 5265
# Batch completed at 11:23:31
# Processed 44 tracks in this batch
# Total tracks processed: 5259
# Last track processed: Yo Odeconer
# Last track genres: ['rhumba']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 106 of 201
# Processing rows 5265 to 5315
# Batch completed at 11:24:30
# Processed 45 tracks in this batch
# Total tracks processed: 5310
# Last track processed: Infected
# Last track genres: ['punk', 'skate punk', 'hardcore punk', 'ska punk', 'melodic hardcore']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 107 of 201
# Processing rows 5315 to 5365
# Batch completed at 11:25:28
# Processed 44 tracks in this batch
# Total tracks processed: 5359
# Last track processed: Love Makin' Mama
# Last track genres: ['blues', 'country blues', 'classic blues', 'ragtime']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 108 of 201
# Processing rows 5365 to 5415
# Error processing track Sanddollars: HTTPSConnectionPool(host='api.spotify.com', port=443): Read timed out. (read timeout=5)
# Batch completed at 11:26:34
# Processed 43 tracks in this batch
# Total tracks processed: 5408
# Last track processed: If You Don't Pray For Me
# Last track genres: No genres found
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 109 of 201
# Processing rows 5415 to 5465
# Batch completed at 11:27:31
# Processed 46 tracks in this batch
# Total tracks processed: 5461
# Last track processed: She Can't Burn Me Now
# Last track genres: ['bluegrass', 'newgrass', 'americana']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 110 of 201
# Processing rows 5465 to 5515
# Batch completed at 11:28:29
# Processed 43 tracks in this batch
# Total tracks processed: 5508
# Last track processed: Dave D. Blues
# Last track genres: ['slowcore']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 111 of 201
# Processing rows 5515 to 5565
# Batch completed at 11:29:29
# Processed 43 tracks in this batch
# Total tracks processed: 5558
# Last track processed: For You Mom & Dad
# Last track genres: ['latin jazz', 'jazz']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 112 of 201
# Processing rows 5565 to 5615
# Batch completed at 11:30:26
# Processed 45 tracks in this batch
# Total tracks processed: 5610
# Last track processed: Amazing
# Last track genres: ['ccm', 'christian', 'christmas', 'christian pop', 'christian country']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 113 of 201
# Processing rows 5615 to 5665
# Batch completed at 11:31:22
# Processed 40 tracks in this batch
# Total tracks processed: 5655
# Last track processed: Theme III
# Last track genres: ['folk metal', 'doom metal', 'gothic metal']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 114 of 201
# Processing rows 5665 to 5715
# Batch completed at 11:32:17
# Processed 45 tracks in this batch
# Total tracks processed: 5710
# Last track processed: My Heart Is Yearning
# Last track genres: ['punk', 'skate punk', 'ska punk', 'melodic hardcore', 'hardcore punk', 'ska']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 115 of 201
# Processing rows 5715 to 5765
# Batch completed at 11:33:09
# Processed 39 tracks in this batch
# Total tracks processed: 5754
# Last track processed: Dance_ Dance_ Dance
# Last track genres: ['classic rock', 'folk rock', 'singer-songwriter', 'roots rock']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 116 of 201
# Processing rows 5765 to 5815
# Batch completed at 11:34:02
# Processed 41 tracks in this batch
# Total tracks processed: 5806
# Last track processed: Gotta Let It Go
# Last track genres: ['mandopop', 'taiwanese pop', 'c-pop']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 117 of 201
# Processing rows 5815 to 5865
# Batch completed at 11:34:57
# Processed 42 tracks in this batch
# Total tracks processed: 5857
# Last track processed: Mr. Prime Minister
# Last track genres: ['doo-wop']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 118 of 201
# Processing rows 5865 to 5915
# Batch completed at 11:35:54
# Processed 42 tracks in this batch
# Total tracks processed: 5907
# Last track processed: Taste Of Dis
# Last track genres: No genres found
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 119 of 201
# Processing rows 5915 to 5965
# Batch completed at 11:36:52
# Processed 44 tracks in this batch
# Total tracks processed: 5959
# Last track processed: Erica
# Last track genres: ['orchestra']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 120 of 201
# Processing rows 5965 to 6015
# Batch completed at 11:37:48
# Processed 42 tracks in this batch
# Total tracks processed: 6007
# Last track processed: Anti Geroi
# Last track genres: ['folk metal', 'melodic death metal', 'pirate metal', 'power metal', 'melodic metal', 'metal', 'folk', 'medieval metal', 'symphonic metal']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 121 of 201
# Processing rows 6015 to 6065
# Batch completed at 11:38:42
# Processed 43 tracks in this batch
# Total tracks processed: 6058
# Last track processed: Donizetti: Roberto Devereux: L'ore trascorrono...
# Last track genres: ['opera']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 122 of 201
# Processing rows 6065 to 6115
# Batch completed at 11:39:37
# Processed 43 tracks in this batch
# Total tracks processed: 6108
# Last track processed: Interlude
# Last track genres: ['k-pop', 'k-rap']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 123 of 201
# Processing rows 6115 to 6165
# Batch completed at 11:40:30
# Processed 44 tracks in this batch
# Total tracks processed: 6159
# Last track processed: Générique - "le gendarme et les gendarmettes
# Last track genres: ['easy listening']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 124 of 201
# Processing rows 6165 to 6215
# Batch completed at 11:41:24
# Processed 46 tracks in this batch
# Total tracks processed: 6211
# Last track processed: Villagers Galloping To Battle
# Last track genres: No genres found
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 125 of 201
# Processing rows 6215 to 6265
# Batch completed at 11:42:17
# Processed 41 tracks in this batch
# Total tracks processed: 6256
# Last track processed: Words With Fat Joe
# Last track genres: ['east coast hip hop']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 126 of 201
# Processing rows 6265 to 6315
# Batch completed at 11:43:14
# Processed 44 tracks in this batch
# Total tracks processed: 6309
# Last track processed: Did You Ever Go Steady
# Last track genres: ['doo-wop', 'motown']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 127 of 201
# Processing rows 6315 to 6365
# Batch completed at 11:44:07
# Processed 44 tracks in this batch
# Total tracks processed: 6359
# Last track processed: Dance_ Dance
# Last track genres: ['emo', 'pop punk']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 128 of 201
# Processing rows 6365 to 6415
# Batch completed at 11:45:05
# Processed 43 tracks in this batch
# Total tracks processed: 6408
# Last track processed: Le Diable
# Last track genres: No genres found
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 129 of 201
# Processing rows 6415 to 6465
# Batch completed at 11:46:02
# Processed 42 tracks in this batch
# Total tracks processed: 6457
# Last track processed: D Solo
# Last track genres: No genres found
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 130 of 201
# Processing rows 6465 to 6515
# Batch completed at 11:46:58
# Processed 42 tracks in this batch
# Total tracks processed: 6507
# Last track processed: If You Don't Somebody Else Will
# Last track genres: ['honky tonk', 'traditional country']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 131 of 201
# Processing rows 6515 to 6565
# Batch completed at 11:47:58
# Processed 42 tracks in this batch
# Total tracks processed: 6557
# Last track processed: No. 284
# Last track genres: ['soca', 'calypso']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 132 of 201
# Processing rows 6565 to 6615
# Batch completed at 11:48:56
# Processed 41 tracks in this batch
# Total tracks processed: 6606
# Last track processed: Each Time I Think Of You
# Last track genres: ['taiwanese pop', 'mandopop', 'c-pop']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 133 of 201
# Processing rows 6615 to 6665
# Batch completed at 11:49:56
# Processed 47 tracks in this batch
# Total tracks processed: 6662
# Last track processed: Boss-Eyed Whelk
# Last track genres: No genres found
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 134 of 201
# Processing rows 6665 to 6715
# Batch completed at 11:50:56
# Processed 47 tracks in this batch
# Total tracks processed: 6712
# Last track processed: In The Midnight Hour
# Last track genres: No genres found
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 135 of 201
# Processing rows 6715 to 6765
# Batch completed at 11:51:54
# Processed 43 tracks in this batch
# Total tracks processed: 6758
# Last track processed: It Feels Like Rain
# Last track genres: ['blues']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 136 of 201
# Processing rows 6765 to 6815
# Batch completed at 11:52:50
# Processed 43 tracks in this batch
# Total tracks processed: 6808
# Last track processed: To the Lions
# Last track genres: ['metalcore', 'hardcore', 'hardcore punk', 'grindcore', 'post-hardcore', 'sludge metal']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 137 of 201
# Processing rows 6815 to 6865
# Batch completed at 11:53:44
# Processed 42 tracks in this batch
# Total tracks processed: 6857
# Last track processed: Less Is More
# Last track genres: ['jungle', 'drum and bass', 'breakbeat']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 138 of 201
# Processing rows 6865 to 6915
# Batch completed at 11:54:38
# Processed 40 tracks in this batch
# Total tracks processed: 6905
# Last track processed: Si Je M'En Sors
# Last track genres: ['variété française', 'french pop', 'chanson']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 139 of 201
# Processing rows 6915 to 6965
# Batch completed at 11:55:36
# Processed 42 tracks in this batch
# Total tracks processed: 6957
# Last track processed: Could You Be Love
# Last track genres: ['power metal', 'heavy metal', 'folk metal']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 140 of 201
# Processing rows 6965 to 7015
# Batch completed at 11:56:34
# Processed 44 tracks in this batch
# Total tracks processed: 7009
# Last track processed: You Don't Get Much
# Last track genres: ['roots rock']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 141 of 201
# Processing rows 7015 to 7065
# Batch completed at 11:57:32
# Processed 45 tracks in this batch
# Total tracks processed: 7060
# Last track processed: Tu Me Desesperas
# Last track genres: ['salsa', 'salsa romantica']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 142 of 201
# Processing rows 7065 to 7115
# Batch completed at 11:58:24
# Processed 37 tracks in this batch
# Total tracks processed: 7102
# Last track processed: Groovin'
# Last track genres: ['hands up', 'happy hardcore', 'eurodance', 'eurotrance']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 143 of 201
# Processing rows 7115 to 7165
# Batch completed at 11:59:23
# Processed 43 tracks in this batch
# Total tracks processed: 7158
# Last track processed: Still
# Last track genres: ['rock', 'post-grunge', 'alternative rock', 'grunge', 'modern rock']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 144 of 201
# Processing rows 7165 to 7215
# Error processing track Sliabh Geal gCua: HTTPSConnectionPool(host='api.spotify.com', port=443): Read timed out. (read timeout=5)
# Batch completed at 12:00:25
# Processed 43 tracks in this batch
# Total tracks processed: 7208
# Last track processed: Lluvias De Cristal
# Last track genres: ['latin jazz', 'smooth jazz', 'jazz']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 145 of 201
# Processing rows 7215 to 7265
# Batch completed at 12:01:22
# Processed 47 tracks in this batch
# Total tracks processed: 7262
# Last track processed: I'm Your Witchdoctor
# Last track genres: ['blues', 'blues rock', 'classic blues']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 146 of 201
# Processing rows 7265 to 7315
# Batch completed at 12:02:21
# Processed 40 tracks in this batch
# Total tracks processed: 7305
# Last track processed: The drifter
# Last track genres: ['lovers rock', 'reggae', 'roots reggae', 'rocksteady', 'dub', 'ragga']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 147 of 201
# Processing rows 7315 to 7365
# Batch completed at 12:03:19
# Processed 49 tracks in this batch
# Total tracks processed: 7364
# Last track processed: The Spinward Marches
# Last track genres: ['power metal', 'heavy metal', 'folk metal']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 148 of 201
# Processing rows 7365 to 7415
# Batch completed at 12:04:15
# Processed 44 tracks in this batch
# Total tracks processed: 7409
# Last track processed: Fool
# Last track genres: ['g-funk', 'mexican hip hop']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 149 of 201
# Processing rows 7415 to 7465
# Batch completed at 12:05:11
# Processed 46 tracks in this batch
# Total tracks processed: 7461
# Last track processed: Sister Sue
# Last track genres: ['country rock', 'southern rock', 'rockabilly']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 150 of 201
# Processing rows 7465 to 7515
# Batch completed at 12:06:05
# Processed 45 tracks in this batch
# Total tracks processed: 7510
# Last track processed: Yesterday
# Last track genres: ['bossa nova']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 151 of 201
# Processing rows 7515 to 7565
# Batch completed at 12:07:02
# Processed 42 tracks in this batch
# Total tracks processed: 7557
# Last track processed: Bury Your Head
# Last track genres: ['post-hardcore', 'screamo', 'emo', 'emocore']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 152 of 201
# Processing rows 7565 to 7615
# Batch completed at 12:07:57
# Processed 40 tracks in this batch
# Total tracks processed: 7605
# Last track processed: Eden
# Last track genres: No genres found
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 153 of 201
# Processing rows 7615 to 7665
# Batch completed at 12:08:55
# Processed 44 tracks in this batch
# Total tracks processed: 7659
# Last track processed: Why can't we live together
# Last track genres: No genres found
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 154 of 201
# Processing rows 7665 to 7715
# Batch completed at 12:09:51
# Processed 39 tracks in this batch
# Total tracks processed: 7704
# Last track processed: La Bambola
# Last track genres: ['bolero']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 155 of 201
# Processing rows 7715 to 7765
# Batch completed at 12:10:47
# Processed 40 tracks in this batch
# Total tracks processed: 7755
# Last track processed: Fear The Sea
# Last track genres: ['gothic metal', 'symphonic metal', 'doom metal', 'symphonic rock', 'progressive metal']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 156 of 201
# Processing rows 7765 to 7815
# Batch completed at 12:11:45
# Processed 46 tracks in this batch
# Total tracks processed: 7811
# Last track processed: Rick's Cafe
# Last track genres: No genres found
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 157 of 201
# Processing rows 7815 to 7865
# Batch completed at 12:12:41
# Processed 42 tracks in this batch
# Total tracks processed: 7857
# Last track processed: I See The Light
# Last track genres: ['garage rock', 'bubblegum pop']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 158 of 201
# Processing rows 7865 to 7915
# Batch completed at 12:13:40
# Processed 47 tracks in this batch
# Total tracks processed: 7912
# Last track processed: Hermitage
# Last track genres: ['jazz fusion', 'jazz']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 159 of 201
# Processing rows 7915 to 7965
# Batch completed at 12:14:36
# Processed 42 tracks in this batch
# Total tracks processed: 7957
# Last track processed: Siempre
# Last track genres: ['glam metal', 'glam rock']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 160 of 201
# Processing rows 7965 to 8015
# Batch completed at 12:15:34
# Processed 43 tracks in this batch
# Total tracks processed: 8008
# Last track processed: All Creatures Of Our God And King
# Last track genres: ['americana', 'folk', 'alt country']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 161 of 201
# Processing rows 8015 to 8065
# Batch completed at 12:16:27
# Processed 40 tracks in this batch
# Total tracks processed: 8055
# Last track processed: Oops!...I Did It Again
# Last track genres: ['pop']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 162 of 201
# Processing rows 8065 to 8115
# Batch completed at 12:17:22
# Processed 43 tracks in this batch
# Total tracks processed: 8108
# Last track processed: Angel
# Last track genres: No genres found
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 163 of 201
# Processing rows 8115 to 8165
# Batch completed at 12:18:18
# Processed 36 tracks in this batch
# Total tracks processed: 8151
# Last track processed: The Child Deirdre
# Last track genres: ['soundtrack']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 164 of 201
# Processing rows 8165 to 8215
# Batch completed at 12:19:17
# Processed 43 tracks in this batch
# Total tracks processed: 8208
# Last track processed: American Lovebite
# Last track genres: No genres found
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 165 of 201
# Processing rows 8215 to 8265
# Batch completed at 12:20:14
# Processed 39 tracks in this batch
# Total tracks processed: 8254
# Last track processed: Oh ! Tannenbaum
# Last track genres: No genres found
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 166 of 201
# Processing rows 8265 to 8315
# Batch completed at 12:21:08
# Processed 42 tracks in this batch
# Total tracks processed: 8307
# Last track processed: We Blame Love
# Last track genres: ['synthpop', 'new wave']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 167 of 201
# Processing rows 8315 to 8365
# Batch completed at 12:22:03
# Processed 47 tracks in this batch
# Total tracks processed: 8362
# Last track processed: Ain't She Sweet
# Last track genres: No genres found
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 168 of 201
# Processing rows 8365 to 8415
# Batch completed at 12:22:59
# Processed 44 tracks in this batch
# Total tracks processed: 8409
# Last track processed: New Milk Cow Blues
# Last track genres: ['rockabilly', 'traditional country', 'honky tonk']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 169 of 201
# Processing rows 8415 to 8465
# Batch completed at 12:23:54
# Processed 42 tracks in this batch
# Total tracks processed: 8457
# Last track processed: Love Is What We Make It
# Last track genres: ['country']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 170 of 201
# Processing rows 8465 to 8515
# Batch completed at 12:24:51
# Processed 43 tracks in this batch
# Total tracks processed: 8508
# Last track processed: Love Is Gone
# Last track genres: ['edm', 'dance']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 171 of 201
# Processing rows 8515 to 8565
# Batch completed at 12:25:45
# Processed 39 tracks in this batch
# Total tracks processed: 8554
# Last track processed: A Piece Of My Heart
# Last track genres: ['post-punk', 'new wave', 'proto-punk', 'funk rock', 'punk']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 172 of 201
# Processing rows 8565 to 8615
# Batch completed at 12:26:40
# Processed 40 tracks in this batch
# Total tracks processed: 8605
# Last track processed: Turn It Up
# Last track genres: ['chanson']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 173 of 201
# Processing rows 8615 to 8665
# Error processing track Filosofia Pura: HTTPSConnectionPool(host='api.spotify.com', port=443): Read timed out. (read timeout=5)
# Batch completed at 12:27:40
# Processed 41 tracks in this batch
# Total tracks processed: 8656
# Last track processed: Pastel
# Last track genres: ['smooth jazz']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 174 of 201
# Processing rows 8665 to 8715
# Batch completed at 12:28:35
# Processed 41 tracks in this batch
# Total tracks processed: 8706
# Last track processed: A Soldiers Intro
# Last track genres: ['rap metal', 'nu metal', 'rap rock', 'alternative metal']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 175 of 201
# Processing rows 8715 to 8765
# Batch completed at 12:29:29
# Processed 38 tracks in this batch
# Total tracks processed: 8753
# Last track processed: valid
# Last track genres: ['melodic techno', 'melodic house']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 176 of 201
# Processing rows 8765 to 8815
# Batch completed at 12:30:26
# Processed 42 tracks in this batch
# Total tracks processed: 8807
# Last track processed: Green Mind
# Last track genres: ['noise rock', 'grunge', 'alternative rock', 'power pop']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 177 of 201
# Processing rows 8815 to 8865
# Batch completed at 12:31:21
# Processed 44 tracks in this batch
# Total tracks processed: 8859
# Last track processed: Requiem Mass in D Minor_ K. 626: VIII. Lacrimosa dies illae
# Last track genres: No genres found
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 178 of 201
# Processing rows 8865 to 8915
# Batch completed at 12:32:17
# Processed 43 tracks in this batch
# Total tracks processed: 8908
# Last track processed: El Perro
# Last track genres: No genres found
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 179 of 201
# Processing rows 8915 to 8965
# Batch completed at 12:33:14
# Processed 44 tracks in this batch
# Total tracks processed: 8959
# Last track processed: Mighty Lak' a Rose
# Last track genres: No genres found
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 180 of 201
# Processing rows 8965 to 9015
# Batch completed at 12:34:10
# Processed 43 tracks in this batch
# Total tracks processed: 9008
# Last track processed: Midnight
# Last track genres: ['blues', 'modern blues']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 181 of 201
# Processing rows 9015 to 9065
# Batch completed at 12:35:05
# Processed 43 tracks in this batch
# Total tracks processed: 9058
# Last track processed: National Fencibles March
# Last track genres: ['exotica', 'adult standards', 'easy listening']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 182 of 201
# Processing rows 9065 to 9115
# Batch completed at 12:36:00
# Processed 42 tracks in this batch
# Total tracks processed: 9107
# Last track processed: Queen Street Rag
# Last track genres: ['ragtime', 'southern gospel']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 183 of 201
# Processing rows 9115 to 9165
# Batch completed at 12:36:59
# Processed 43 tracks in this batch
# Total tracks processed: 9158
# Last track processed: En mis besos
# Last track genres: ['bolero', 'rock en español']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 184 of 201
# Processing rows 9165 to 9215
# Batch completed at 12:37:56
# Processed 43 tracks in this batch
# Total tracks processed: 9208
# Last track processed: Joaquin Torres Jr.
# Last track genres: ['corrido', 'norteño', 'música mexicana']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 185 of 201
# Processing rows 9215 to 9265
# Batch completed at 12:38:52
# Processed 46 tracks in this batch
# Total tracks processed: 9261
# Last track processed: Tras La Reja
# Last track genres: ['son cubano', 'bolero']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 186 of 201
# Processing rows 9265 to 9315
# Batch completed at 12:39:49
# Processed 41 tracks in this batch
# Total tracks processed: 9306
# Last track processed: Completeness
# Last track genres: No genres found
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 187 of 201
# Processing rows 9315 to 9365
# Batch completed at 12:40:46
# Processed 46 tracks in this batch
# Total tracks processed: 9361
# Last track processed: Never Tell
# Last track genres: ['jangle pop']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 188 of 201
# Processing rows 9365 to 9415
# Batch completed at 12:41:41
# Processed 43 tracks in this batch
# Total tracks processed: 9408
# Last track processed: Death Or Glory
# Last track genres: ['punk']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 189 of 201
# Processing rows 9415 to 9465
# Batch completed at 12:42:36
# Processed 40 tracks in this batch
# Total tracks processed: 9455
# Last track processed: Las Muchachas
# Last track genres: ['salsa', 'merengue', 'mambo']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 190 of 201
# Processing rows 9465 to 9515
# Error processing track This One's For You: HTTPSConnectionPool(host='api.spotify.com', port=443): Read timed out. (read timeout=5)
# Batch completed at 12:43:36
# Processed 41 tracks in this batch
# Total tracks processed: 9506
# Last track processed: Gyere velem
# Last track genres: No genres found
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 191 of 201
# Processing rows 9515 to 9565
# Batch completed at 12:44:31
# Processed 44 tracks in this batch
# Total tracks processed: 9559
# Last track processed: Ke T' Oniro Egine Efialtis
# Last track genres: ['laïko', 'entehno']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 192 of 201
# Processing rows 9565 to 9615
# Batch completed at 12:45:26
# Processed 43 tracks in this batch
# Total tracks processed: 9608
# Last track processed: Speak Low
# Last track genres: ['bossa nova', 'brazilian jazz', 'latin jazz', 'jazz', 'cool jazz']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 193 of 201
# Processing rows 9615 to 9665
# Batch completed at 12:46:20
# Processed 42 tracks in this batch
# Total tracks processed: 9657
# Last track processed: Getto Boys
# Last track genres: ['organic house', 'progressive house', 'melodic house', 'progressive trance']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 194 of 201
# Processing rows 9665 to 9715
# Batch completed at 12:47:13
# Processed 39 tracks in this batch
# Total tracks processed: 9704
# Last track processed: Con el chacacha del tren
# Last track genres: ['flamenco', 'flamenco pop']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 195 of 201
# Processing rows 9715 to 9765
# Batch completed at 12:48:09
# Processed 41 tracks in this batch
# Total tracks processed: 9756
# Last track processed: C'est pas ma faute
# Last track genres: ['rhumba', 'azonto', 'zouk']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 196 of 201
# Processing rows 9765 to 9815
# Batch completed at 12:49:05
# Processed 40 tracks in this batch
# Total tracks processed: 9805
# Last track processed: Burning Skies
# Last track genres: ['post-punk', 'deathrock', 'darkwave', 'cold wave', 'new wave']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 197 of 201
# Processing rows 9815 to 9865
# Batch completed at 12:50:04
# Processed 49 tracks in this batch
# Total tracks processed: 9864
# Last track processed: Los De Aragón: "Los De Aragón
# Last track genres: ['flamenco']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 198 of 201
# Processing rows 9865 to 9915
# Batch completed at 12:51:01
# Processed 44 tracks in this batch
# Total tracks processed: 9909
# Last track processed: Chaos
# Last track genres: ['punk', 'ska punk', 'hardcore punk']
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 199 of 201
# Processing rows 9915 to 9965
# Batch completed at 12:51:58
# Processed 46 tracks in this batch
# Total tracks processed: 9961
# Last track processed: A Talk With Dad
# Last track genres: No genres found
# Sleeping for 30 seconds...
# --------------------------------------------------
#
# Processing batch 200 of 201
# Processing rows 9965 to 10000
# HTTP Error for GET to https://api.spotify.com/v1/search with Params: {'q': 'track:Turandot _ Act III - Scene I: Nessum dorma! artist:Maria Callas/Eugenio Fernandi/Elisabeth Schwarzkopf/Giuseppe Nessi/Nicola Zaccaria/Mario Borriello/Renato Ercolani/Piero de Palma/Giulio Mauri/Elisabetta Fusco/Pinuccia Perotti/Coro del Teatro alla Scala_ Milano/Orchestra del Teatro alla Scala_ Milano/Tul', 'limit': 1, 'offset': 0, 'type': 'track', 'market': None} returned 400 due to Query exceeds maximum length of 250 characters
# Error processing track Turandot _ Act III - Scene I: Nessum dorma!: http status: 400, code:-1 - https://api.spotify.com/v1/search?q=track%3ATurandot+_+Act+III+-+Scene+I%3A+Nessum+dorma%21+artist%3AMaria+Callas%2FEugenio+Fernandi%2FElisabeth+Schwarzkopf%2FGiuseppe+Nessi%2FNicola+Zaccaria%2FMario+Borriello%2FRenato+Ercolani%2FPiero+de+Palma%2FGiulio+Mauri%2FElisabetta+Fusco%2FPinuccia+Perotti%2FCoro+del+Teatro+alla+Scala_+Milano%2FOrchestra+del+Teatro+alla+Scala_+Milano%2FTul&limit=1&offset=0&type=track:
#  Query exceeds maximum length of 250 characters, reason: None
# Batch completed at 12:52:45
# Processed 30 tracks in this batch
# Total tracks processed: 9995
# Last track processed: Souffle 2
# Last track genres: No genres found
#
# All batches processed!
# Final total tracks processed: 9995
